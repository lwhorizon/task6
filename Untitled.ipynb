# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
plt.plot(np.random.randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
from numpy.random import randn

# %%
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')
plt.legend(loc='best')

# %%
plt.plot(data, 'k--', label='Default')

plt.plot(data, 'k-', label='steps-post', drawstyle='steps-post')

plt.legend(loc='best')

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])

# %%
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

# %%
ax.set_title('My first matplotlib plot')
# Out:
# Text(0.5, 1.0, 'My first matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
ax.plot(randn(1000).cumsum())

# %%
props = {
'title': 'My first matplotlib plot',
'xlabel': 'Stages'
}
ax.set(**props)
# Out:
# [Text(0.5, 0, 'Stages'), Text(0.5, 1.0, 'My first matplotlib plot')]

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(randn(1000).cumsum(), 'k', label='one')

# %%
ax.plot(randn(1000).cumsum(), 'k--', label='two')

# %%
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')

# %%
fig = plt.figure(); 

ax = fig.add_subplot(1, 1, 1)

ax.plot(randn(1000).cumsum(), 'k', label='one')

ax.plot(randn(1000).cumsum(), 'k--', label='two')

ax.plot(randn(1000).cumsum(), 'k.', label='three')

ax.legend(loc='best')

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=1)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=1)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=1)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
from io import BytesIO
buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %%
s =  pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

s.plot()

# %%
df = pd.DataFrame(randn(10, 4).cumsum(0),columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
# Out:
#            A         B         C         D
# 0   0.779845 -0.802428  0.639600 -1.120030
# 10 -0.559760 -0.743589  0.783747 -1.789586
# 20  0.516450 -0.789801 -0.019736  0.059275
# 30 -0.126903 -0.124695 -0.566919  1.337831
# 40 -1.307424  0.183481  1.578109  1.041789
# 50 -1.159767 -0.072565  3.478091 -1.981626
# 60 -0.253614 -1.624242  2.451938 -1.374386
# 70  0.914934 -1.050600  1.453700 -0.945869
# 80  2.228833 -0.914953  0.326110 -0.822046
# 90  1.716508 -2.540356  0.073317 -2.410049

# %%
df.plot()

# %%
fig, axes = plt.subplots(2, 1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='k', alpha=0.7)

data.plot.barh(ax=axes[1], color='k', alpha=0.7)

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

df
# Out:
# Genus         A         B         C         D
# one    0.786183  0.348484  0.742909  0.465922
# two    0.641158  0.661160  0.632871  0.912069
# three  0.123221  0.107184  0.604115  0.655004
# four   0.858169  0.644508  0.488464  0.071830
# five   0.215375  0.040215  0.232682  0.095001
# six    0.907627  0.137211  0.127957  0.426976

# %%
df.plot.bar()

# %%
df.plot.barh( alpha=1)

# %%
tips = pd.read_csv('tips.csv')

tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# 5         25.29  4.71     No   Sun  Dinner     4
# 6          8.77  2.00     No   Sun  Dinner     2
# 7         26.88  3.12     No   Sun  Dinner     4
# 8         15.04  1.96     No   Sun  Dinner     2
# 9         14.78  3.23     No   Sun  Dinner     2
# 10        10.27  1.71     No   Sun  Dinner     2
# 11        35.26  5.00     No   Sun  Dinner     4
# 12        15.42  1.57     No   Sun  Dinner     2
# 13        18.43  3.00     No   Sun  Dinner     4
# 14        14.83  3.02     No   Sun  Dinner     2
# 15        21.58  3.92     No   Sun  Dinner     2
# 16        10.33  1.67     No   Sun  Dinner     3
# 17        16.29  3.71     No   Sun  Dinner     3
# 18        16.97  3.50     No   Sun  Dinner     3
# 19        20.65  3.35     No   Sat  Dinner     3
# 20        17.92  4.08     No   Sat  Dinner     2
# 21        20.29  2.75     No   Sat  Dinner     2
# 22        15.77  2.23     No   Sat  Dinner     2
# 23        39.42  7.58     No   Sat  Dinner     4
# 24        19.82  3.18     No   Sat  Dinner     2
# 25        17.81  2.34     No   Sat  Dinner     4
# 26        13.37  2.00     No   Sat  Dinner     2
# 27        12.69  2.00     No   Sat  Dinner     2
# 28        21.70  4.30     No   Sat  Dinner     2
# 29        19.65  3.00     No   Sat  Dinner     2
# ..          ...   ...    ...   ...     ...   ...
# 214       28.17  6.50    Yes   Sat  Dinner     3
# 215       12.90  1.10    Yes   Sat  Dinner     2
# 216       28.15  3.00    Yes   Sat  Dinner     5
# 217       11.59  1.50    Yes   Sat  Dinner     2
# 218        7.74  1.44    Yes   Sat  Dinner     2
# 219       30.14  3.09    Yes   Sat  Dinner     4
# 220       12.16  2.20    Yes   Fri   Lunch     2
# 221       13.42  3.48    Yes   Fri   Lunch     2
# 222        8.58  1.92    Yes   Fri   Lunch     1
# 223       15.98  3.00     No   Fri   Lunch     3
# 224       13.42  1.58    Yes   Fri   Lunch     2
# 225       16.27  2.50    Yes   Fri   Lunch     2
# 226       10.09  2.00    Yes   Fri   Lunch     2
# 227       20.45  3.00     No   Sat  Dinner     4
# 228       13.28  2.72     No   Sat  Dinner     2
# 229       22.12  2.88    Yes   Sat  Dinner     2
# 230       24.01  2.00    Yes   Sat  Dinner     4
# 231       15.69  3.00    Yes   Sat  Dinner     3
# 232       11.61  3.39     No   Sat  Dinner     2
# 233       10.77  1.47     No   Sat  Dinner     2
# 234       15.53  3.00    Yes   Sat  Dinner     2
# 235       10.07  1.25     No   Sat  Dinner     2
# 236       12.60  1.00    Yes   Sat  Dinner     2
# 237       32.83  1.17    Yes   Sat  Dinner     2
# 238       35.83  4.67     No   Sat  Dinner     3
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
party_count = pd.crosstab(tips['day'], tips['size'])

party_count
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_pcts  = party_count.div(party_count.sum(1), axis=0)

party_pcts
# Out:
# size         1         2         3         4         5         6
# day
# Fri   0.052632  0.842105  0.052632  0.052632  0.000000  0.000000
# Sat   0.022989  0.609195  0.206897  0.149425  0.011494  0.000000
# Sun   0.000000  0.513158  0.197368  0.236842  0.039474  0.013158
# Thur  0.016129  0.774194  0.064516  0.080645  0.016129  0.048387

# %%
party_pcts.plot.bar()

# %%
party_count.plot.barh()

# %%
 import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
tips['tip_pct'].plot.density()

# %%
comp1 = np.random.normal(0, 1, size=200)

comp2 = np.random.normal(10, 2, size=200)

# %%
values = pd.Series(np.concatenate([comp1, comp2]))

# %%
sns.distplot(values, bins=100, color='k')

# %%
macro = pd.read_csv('macrodata.csv')

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

# %%
trans_data = np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot('m1', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
 sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker', kind='bar', data=tips[tips.tip_pct < 1])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day', y='tip_pct', row='time',             col='smoker',
           kind='bar', data=tips[tips.tip_pct < 1])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='tip_pct', y='day', kind='box', data=tips[tips.tip_pct < 0.5])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
feature_dict = {i:label for i,label in zip(
            range(4),
              ('sepal length in cm', 
              'sepal width in cm', 
              'petal length in cm', 
              'petal width in cm', ))}

df=pd.read_csv("iris.csv",header=None,sep=',')

df.columns = [l for i,l in sorted(feature_dict.items())] + ['class label']
df.dropna(how="all", inplace=True) 

df.tail()
# Out:
#     sepal length in cm sepal width in cm petal length in cm petal width in cm  \
# 146                6.7                 3                5.2               2.3
# 147                6.3               2.5                  5               1.9
# 148                6.5                 3                5.2                 2
# 149                6.2               3.4                5.4               2.3
# 150                5.9                 3                5.1               1.8
#
#     class label
# 146   virginica
# 147   virginica
# 148   virginica
# 149   virginica
# 150   virginica

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X = df.iloc[1:4].values

y = df['class label'].values

# %%
X
# Out:
# array([['5.1', '3.5', '1.4', '0.2', 'setosa'],
#        ['4.9', '3', '1.4', '0.2', 'setosa'],
#        ['4.7', '3.2', '1.3', '0.2', 'setosa']], dtype=object)

# %%
enc = LabelEncoder()
le = enc.fit(y)
y = le.transform(y)

# %%
label_dict = {0: 'Setosa', 1: 'Versicolor', 2:'Virginica'}

attr_dict = {0: 'sepal length', 
            1:  'sepal width', 
            2:  'petal length', 
            3:  'petal width'}

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.pie(
    [X[y==i].shape[0] for i in range(3)],
    labels=[label_dict[i] for i in range(3)],
    shadow=True,
    colors=('yellowgreen', 'lightskyblue', 'gold'),
    startangle=90,      
    autopct='%1.1f%%',  
    )

plt.legend(fancybox=True, loc='lower right')

plt.title('Class distribution of the 3 different flower species')
plt.axis('equal')    
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-226-24af7d8b14be> in <module>
#       3
#       4 plt.pie(
# ----> 5     [X[y==i].shape[0] for i in range(3)],
#       6     labels=[label_dict[i] for i in range(3)],
#       7     shadow=True,
#
# <ipython-input-226-24af7d8b14be> in <listcomp>(.0)
#       3
#       4 plt.pie(
# ----> 5     [X[y==i].shape[0] for i in range(3)],
#       6     labels=[label_dict[i] for i in range(3)],
#       7     shadow=True,
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 3 but corresponding boolean dimension is 151

# %%
import matplotlib.pyplot as plt

mean_vals = [X[y==i,:].mean(axis=0) for i in range(3)]

labels = [attr_dict[i] for i in range(4)]


pos = np.arange(4)
width = 0.2 
    

fig, ax = plt.subplots(figsize=(8,6))

plt.bar(pos, mean_vals[0], width,
                 alpha=0.5,
                 color='g',
                 label=labels[0])

plt.bar([p + width for p in pos], mean_vals[1], width,
                 alpha=0.5,
                 color='b',
                 label=labels[1])
    
plt.bar([p + width*2 for p in pos], mean_vals[2], width,
                 alpha=0.5,
                 color='r',
                 label=labels[2])


ax.set_ylabel('cm')
ax.set_title('Average values for the flower dimensions')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(labels)


plt.xlim(min(pos)-width, max(pos)+width*4)



plt.legend([label_dict[i] for i in range(3)], loc='upper right')


ax.yaxis.grid(True) 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-209-c1f26b931d6b> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 mean_vals = [X[y==i,:].mean(axis=0) for i in range(3)]
#       4
#       5 labels = [attr_dict[i] for i in range(4)]
#
# <ipython-input-209-c1f26b931d6b> in <listcomp>(.0)
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 mean_vals = [X[y==i,:].mean(axis=0) for i in range(3)]
#       4
#       5 labels = [attr_dict[i] for i in range(4)]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 151

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.subplot(111)

bplot = plt.boxplot([X[y==i,3] for i in range(3)],
        notch=True,          
        vert=True,           
        sym='ko',            
        patch_artist=True)   


colors = ['pink', 'lightblue', 'lightgreen']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)


for whisker in bplot['whiskers']:
    whisker.set(color='black', linewidth=1.2, linestyle='-')    
    

for cap in bplot['caps']:
    cap.set(linewidth=1.2)
    

plt.tick_params(axis="both", which="both", bottom="off", top="off",  
        labelbottom="on", left="off", right="off", labelleft="on")


ax.yaxis.grid(True)

plt.xticks([y+1 for y in range(4)],
           [label_dict[i] for i in range(3)])
plt.ylim([0,3])

plt.title('Petal widths of the three different flower species')
plt.ylabel('cm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-210-25c65bfbd60a> in <module>
#       2 ax = plt.subplot(111)
#       3
# ----> 4 bplot = plt.boxplot([X[y==i,3] for i in range(3)],
#       5         notch=True,
#       6         vert=True,
#
# <ipython-input-210-25c65bfbd60a> in <listcomp>(.0)
#       2 ax = plt.subplot(111)
#       3
# ----> 4 bplot = plt.boxplot([X[y==i,3] for i in range(3)],
#       5         notch=True,
#       6         vert=True,
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 151

# %%
import math

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,6))

for ax,cnt in zip(axes.ravel(), range(4)):


    min_b = math.floor(np.min(X[:,cnt]))
    max_b = math.ceil(np.max(X[:,cnt]))
    bins = np.linspace(min_b, max_b, 25)


    for lab,col in zip(range(3), ('blue', 'red', 'green')):
        ax.hist(X[y==lab, cnt],
                   color=col, 
                   label='%s' %label_dict[lab], 
                   bins=bins,
                   alpha=0.5,)
    ylims = ax.get_ylim()


    leg = ax.legend(loc='upper right', fancybox=True, fontsize=8)
    ax.set_ylim([0, max(ylims)+2])
    ax.set_xlabel(feature_dict[cnt])
    ax.set_title('Iris histogram #%s' %str(cnt+1))
    

    ax.yaxis.grid(True)


    ax.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")


    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False) 
    ax.spines["bottom"].set_visible(False) 
    ax.spines["left"].set_visible(False)

axes[0][0].set_ylabel('count')
axes[1][0].set_ylabel('count')

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-424bcb27cb60> in <module>
#       6
#       7
# ----> 8     min_b = math.floor(np.min(X[:,cnt]))
#       9     max_b = math.ceil(np.max(X[:,cnt]))
#      10     bins = np.linspace(min_b, max_b, 25)
#
# TypeError: must be real number, not str

# %%
fig = plt.figure(figsize=(6,6))

hist, xedges, yedges = np.histogram2d(X[y==0,2], X[y==0,3])

plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.title('Petal dimensions of Setosa')
plt.imshow(hist)
plt.grid(True)
plt.colorbar()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-212-5086ff223707> in <module>
#       1 fig = plt.figure(figsize=(6,6))
#       2
# ----> 3 hist, xedges, yedges = np.histogram2d(X[y==0,2], X[y==0,3])
#       4
#       5 plt.xlabel('petal length (cm)')
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 151

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
x1, y1 = np.copy(X[:,2]), np.copy(X[:,3])
hist, xedges, yedges = np.histogram2d(x1, y1, bins=4)

elements = (len(xedges) - 1) * (len(yedges) - 1)
xpos, ypos = np.meshgrid(xedges[:-1]+0.25, yedges[:-1]+0.25)

xpos = xpos.flatten()
ypos = ypos.flatten()
zpos = np.zeros(elements)
dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.set_xlabel('petal length (cm)')
ax.set_ylabel('petal width (cm)')
ax.set_zlabel('count')
plt.title('Petal length and width distributions for all samples')

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-9b0299571c87> in <module>
#       4 ax = fig.add_subplot(111, projection='3d')
#       5 x1, y1 = np.copy(X[:,2]), np.copy(X[:,3])
# ----> 6 hist, xedges, yedges = np.histogram2d(x1, y1, bins=4)
#       7
#       8 elements = (len(xedges) - 1) * (len(yedges) - 1)
#
# E:\Anaconda\lib\site-packages\numpy\lib\twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     698         xedges = yedges = asarray(bins)
#     699         bins = [xedges, yedges]
# --> 700     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     701     return hist, edges[0], edges[1]
#     702
#
# E:\Anaconda\lib\site-packages\numpy\lib\histograms.py in histogramdd(sample, bins, range, normed, weights, density)
#    1029                 raise ValueError(
#    1030                     '`bins[{}]` must be positive, when an integer'.format(i))
# -> 1031             smin, smax = _get_outer_edges(sample[:,i], range[i])
#    1032             edges[i] = np.linspace(smin, smax, bins[i] + 1)
#    1033         elif np.ndim(bins[i]) == 1:
#
# E:\Anaconda\lib\site-packages\numpy\lib\histograms.py in _get_outer_edges(a, range)
#     311     else:
#     312         first_edge, last_edge = a.min(), a.max()
# --> 313         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     314             raise ValueError(
#     315                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

colors = ['blue', 'red', 'green']
markers = ['s', 'o', '^']

for lab, c, m in zip(range(3), colors, markers):
    ax.scatter(X[y==lab, 2], X[y==lab, 3], 
               c=c,      # color
               marker=m, # marker symbol
               s=40,     # markersize
               alpha=0.4, # transparency
               label=label_dict[lab]
               )

ax.set_xlabel('petal height (cm)')
ax.set_ylabel('petal width (cm)')
plt.legend(loc='upper left')
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-214-ec8ec8d69e88> in <module>
#       6
#       7 for lab, c, m in zip(range(3), colors, markers):
# ----> 8     ax.scatter(X[y==lab, 2], X[y==lab, 3],
#       9                c=c,      # color
#      10                marker=m, # marker symbol
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 151
